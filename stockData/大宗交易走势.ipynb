# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 20)

# %%
hkws = pd.read_csv('hkws_dzjy.csv', encoding='GBK')

hkws['month'] = hkws.tradeDate.str.slice(0,7)

hkws.groupby('month').tradeVol.sum()
# Out:
# month
# 2011-01       4.30
# 2011-08    1628.00
# 2012-02     470.00
# 2012-03    1385.00
# 2012-05    1346.00
#             ...
# 2016-06    2802.98
# 2016-07     502.49
# 2016-08      20.00
# 2016-09     365.47
# 2016-10     422.42
# Name: tradeVol, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
hkws.groupby('month').tradeVol.sum().plot(kind="bar")

# %%
kdxf = pd.read_csv('kdxf_dzjy.csv', encoding='GBK')

kdxf['month'] = kdxf.tradeDate.str.slice(0,7)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
kdxf.groupby('month').tradeVol.sum().plot(kind="bar")

# %%
kdxf
# Out:
#     Unnamed: 0   tradeDate        secID  ticker assetClass exchangeCD  \
# 0            0  2009-07-23  002230.XSHE    2230          E       XSHE
# 1            1  2011-05-19  002230.XSHE    2230          E       XSHE
# 2            2  2011-05-19  002230.XSHE    2230          E       XSHE
# 3            3  2011-05-19  002230.XSHE    2230          E       XSHE
# 4            4  2011-05-19  002230.XSHE    2230          E       XSHE
# 5            5  2011-05-19  002230.XSHE    2230          E       XSHE
# 6            6  2011-05-19  002230.XSHE    2230          E       XSHE
# 7            7  2011-05-19  002230.XSHE    2230          E       XSHE
# 8            8  2011-05-19  002230.XSHE    2230          E       XSHE
# 9            9  2011-05-19  002230.XSHE    2230          E       XSHE
# 10          10  2011-05-19  002230.XSHE    2230          E       XSHE
# 11          11  2011-05-19  002230.XSHE    2230          E       XSHE
# ...

# %%
mdjt = pd.read_csv('mdjt_dzjy.csv', encoding='GBK')

mdjt['month'] = mdjt.tradeDate.str.slice(0,7)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
mdjt.groupby('month').tradeVol.sum().plot(kind="bar")

# %%
mdjt
# Out:
#      Unnamed: 0   tradeDate        secID  ticker assetClass exchangeCD  \
# 0             0  2014-04-08  000333.XSHE     333          E       XSHE
# 1             1  2014-05-30  000333.XSHE     333          E       XSHE
# 2             2  2014-06-12  000333.XSHE     333          E       XSHE
# 3             3  2014-07-09  000333.XSHE     333          E       XSHE
# 4             4  2014-07-10  000333.XSHE     333          E       XSHE
# ..          ...         ...          ...     ...        ...        ...
# 409         409  2016-10-19  000333.XSHE     333          E       XSHE
# 410         410  2016-10-20  000333.XSHE     333          E       XSHE
# 411         411  2016-10-21  000333.XSHE     333          E       XSHE
# 412         412  2016-10-24  000333.XSHE     333          E       XSHE
# 413         413  2016-10-25  000333.XSHE     333          E       XSHE
#
#     secFullName currencyCD  tradePrice  tradeVal  tradeVol  \
# ...
