# %%
# Histogram

from bokeh.charts import Histogram, show, output_notebook
from bokeh.sampledata.autompg import autompg as df
output_notebook()
from IPython.display import display
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4d36ed47-651e-4ce6-ac15-d0241df10a0b">Loading BokehJS ...</span>
#     </div>

# %%
display(df.columns)
display(df.head())
# Out:
# Index([u'mpg', u'cyl', u'displ', u'hp', u'weight', u'accel', u'yr', u'origin',
#        u'name'],
#       dtype='object')
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
df.sort_values('cyl', inplace=True, ascending=True)
df.head()
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin             name
# 331  23.7    3   70.0  100    2420   12.5  80       3    mazda rx-7 gs
# 241  21.5    3   80.0  110    2720   13.5  77       3       mazda rx-4
# 70   19.0    3   70.0   97    2330   13.5  72       3  mazda rx2 coupe
# 110  18.0    3   70.0   90    2124   13.5  73       3        maxda rx3
# 333  32.4    4  107.0   72    2290   17.0  80       3     honda accord

# %%
hist = Histogram(df, values='weight', color = 'origin',
                 title="HP Distribution by Cylinder Count", legend='top_right')

# %%
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="86a4129d-92f2-4c8f-86a7-8e1b89f73fb5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("86a4129d-92f2-4c8f-86a7-8e1b89f73fb5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '86a4129d-92f2-4c8f-86a7-8e1b89f73fb5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"081bdd24-52ae-43a1-b26c-a287bcf36f5c":{"roots":{"references":[{"attributes":{"axis_label":"weight","formatter":{"id":"1494b3fd-49f4-4f9e-8cf9-e4deaf1e14b8","type":"BasicTickFormatter"},"plot":{"id":"4fbb8aba-4160-49f8-8ded-0dfb4c5affd7","subtype":"Chart","type":"Plot"},"ticker":{"id":"da26e8af-403b-4143-a180-8a9b77351295","type":"BasicTicker"}},"id":"31cc2a45-2d5b-4f74-9195-a9027dde256b","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(3470.0, 3887.5]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[34.0],"label":["(3470.0, 3887.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[417.5],"x":["3678.75"],"y":[17.0]}},"id":"decddf10-26fb-4dc5-a425-95e1654215bd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":