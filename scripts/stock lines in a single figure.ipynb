# %%
# Creating a Plot to Share

import pandas as pd
import matplotlib as plt
import seaborn as sn
from bokeh.plotting import figure
from IPython.display import display
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

# %%
### How to access and download stock data from Uqer.io? 

# code to be ran inside Uqer.io
# dailydata = DataAPI.MktEqudAdjGet(ticker = '002594' ,beginDate=u"",endDate=u"",field=u"secShortName,tradeDate,openPrice,highestPrice,lowestPrice,closePrice,turnoverVol,marketValue,turnoverRate",pandas="1")
# dailydata.head()
# dailydata.to_csv("byd.csv", encoding="GBK") 

# SZZS = DataAPI.MktIdxdGet(tradeDate=u"",indexID=u"",ticker=u"000001",beginDate=u"20110630",endDate=u"",field=u"ticker,tradeDate,openIndex,lowestIndex,highestIndex,closeIndex,turnoverVol",pandas="1")
# SZZS.head()
# SZZS.to_csv("szzs.csv", encoding="GBK") 

# code to be ran inside Uqer.io
# dailydata = DataAPI.MktEqudAdjGet(ticker = '000333' ,beginDate=u"",endDate=u"",field=u"secShortName,tradeDate,openPrice,highestPrice,lowestPrice,closePrice,turnoverVol,marketValue,turnoverRate",pandas="1")
# dailydata.head()
# dailydata.to_csv("mdjt.csv", encoding="GBK")

# %%
BYD = pd.read_csv('../data/byd.csv', parse_dates=['tradeDate'])
SZZS = pd.read_csv('../data/szzs.csv', parse_dates=['tradeDate'])
MDJT = pd.read_csv('../data/mdjt.csv', parse_dates=['tradeDate'])

### Make sure date is parsed

BYD.dtypes
# Out:
# Unnamed: 0               int64
# secShortName            object
# tradeDate       datetime64[ns]
# openPrice              float64
# highestPrice           float64
# lowestPrice            float64
# closePrice             float64
# turnoverVol              int64
# marketValue              int64
# turnoverRate           float64
# dtype: object

# %%
display(BYD.columns)
display(SZZS.columns)
display(MDJT.columns)
# Out:
# Index([u'Unnamed: 0', u'secShortName', u'tradeDate', u'openPrice',
#        u'highestPrice', u'lowestPrice', u'closePrice', u'turnoverVol',
#        u'marketValue', u'turnoverRate'],
#       dtype='object')
# Index([u'Unnamed: 0', u'ticker', u'tradeDate', u'openIndex', u'lowestIndex',
#        u'highestIndex', u'closeIndex', u'turnoverVol'],
#       dtype='object')
# Index([u'Unnamed: 0', u'secShortName', u'tradeDate', u'openPrice',
#        u'highestPrice', u'lowestPrice', u'closePrice', u'turnoverVol',
#        u'marketValue', u'turnoverRate'],
#       dtype='object')

# %%
list(BYD.columns[0:2])
BYD.drop(list(BYD.columns[0:2]), inplace=True, axis=1)

list(SZZS.columns[0:3])
SZZS.drop(list(SZZS.columns[0:2]), inplace=True, axis=1)

list(MDJT.columns[0:3])
MDJT.drop(list(MDJT.columns[0:2]), inplace=True, axis=1)

# %%
BYD.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value', 'Rage']
SZZS.columns = ['Date', 'Open', 'Low', 'High', 'Close', 'Volume']
MDJT.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value', 'Rate']

# %%
### Add priceMultiple column

BYD['priceMult'] = BYD.Close/BYD.loc[0,'Close']
SZZS['priceMult'] = SZZS.Close/SZZS.loc[0,'Close']
MDJT['priceMult'] = MDJT.Close/MDJT.loc[0,'Close']

display(BYD)#.head()
display(SZZS)
display(MDJT)
# Out:
#            Date    Open    High     Low   Close    Volume         Value  \
# 0    2011-06-30  21.979  26.165  21.979  25.425  56292536   59911845000
# 1    2011-07-01  25.745  27.973  24.976  27.973  33561280   65914800000
# 2    2011-07-04  28.852  30.770  28.552  30.770  21964592   72506280000
# 3    2011-07-05  32.748  33.847  31.859  33.018  38108084   77803005000
# 4    2011-07-06  32.768  35.516  32.079  33.368  31296720   78626940000
# ...         ...     ...     ...     ...     ...       ...           ...
# 1255 2016-08-25  58.960  58.960  57.630  58.200   6534826  158777916780
# 1256 2016-08-26  58.500  58.500  58.000  58.350   4416357  159187138215
# 1257 2016-08-29  58.850  59.130  58.150  58.290   6737327  159023449641
# 1258 2016-08-30  58.400  58.540  58.150  58.470   3955193  159514515363
# 1259 2016-08-31  58.630  58.640  58.200  58.550   2802645  159732766795
#
#         Rage  priceMult
# 0     0.8796   1.000000
# 1     0.5244   1.100216
# 2     0.3432   1.210226
# ...

# %%
# AAPL = pd.read_csv(
#     "http://ichart.yahoo.com/table.csv?s=AAPL&a=0&b=1&c=2000&d=0&e=1&f=2015",
#     parse_dates=['Date'])
# MSFT = pd.read_csv(
#     "http://ichart.yahoo.com/table.csv?s=MSFT&a=0&b=1&c=2000&d=0&e=1&f=2015",
#     parse_dates=['Date'])
# IBM = pd.read_csv(
#     "http://ichart.yahoo.com/table.csv?s=IBM&a=0&b=1&c=2000&d=0&e=1&f=2015",
#     parse_dates=['Date'])

def stock_chart():
    p = figure(x_axis_type="datetime", width=800, height=500)

    p.line(BYD['Date'], BYD['priceMult'], color='#A6CEE3', legend='BYD')
    p.line(SZZS['Date'], SZZS['priceMult'], color='#33A02C', legend='SZZS')
    p.line(MDJT['Date'], MDJT['priceMult'], color='#FB9A99', legend='MDJT')

    p.title.text = "Stock Closing Prices"
    p.grid.grid_line_alpha=0.3
    p.xaxis.axis_label = 'Date'
    p.yaxis.axis_label = 'Price'
    p.legend.location = "top_left"
    return p

# %% [markdown]
# Embed functions all look for a Plot object. Common plot objects are:
#  * `Plot` from models
#  * `figure` from plotting
#  * `Chart` from charts
#  * `row`, `column` from layouts

# %%
# Displaying in the Notebook

from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10202359-d3a2-41fb-a98c-1653c83b03b8">Loading BokehJS ...</span>
#     </div>

# %%
p = stock_chart()
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1124df0f-7371-4d76-9f43-ef01c2f27b83"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
# ...
